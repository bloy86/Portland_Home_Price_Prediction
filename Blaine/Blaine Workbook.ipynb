# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_csv("redfin_portland.csv")

# %%
data.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE             ADDRESS  \
# 0  MLS Listing        NaN  Single Family Residential    11447 Brandow St
# 1  MLS Listing        NaN                  Townhouse  6726 SW Canyon Ter
# 2  MLS Listing        NaN  Single Family Residential   20414 Highway 213
# 3  MLS Listing        NaN                  Townhouse    7833 SW Alder St
# 4  MLS Listing        NaN  Single Family Residential  6393 SE Yamhill St
#
#           CITY STATE OR PROVINCE  ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  \
# 0  Oregon City                OR               97045   595000   4.0    3.0
# 1     Portland                OR               97225   475000   2.0    2.5
# 2  Oregon City                OR               97045   450000   3.0    2.0
# 3       Tigard                OR               97224   419900   3.0    2.5
# 4     Portland                OR               97215  1295000   4.0    3.0
#
#    ...  STATUS  NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0  ...  Active                         NaN                       NaN
# 1  ...  Active     August-22-2020 11:00 AM   August-22-2020 01:00 PM
# 2  ...  Active                         NaN                       NaN
# 3  ...  Active                         NaN                       NaN
# 4  ...  Active                         NaN                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/OR/Oregon-City/11447-Bra...
# 1  http://www.redfin.com/OR/Portland/6726-SW-Cany...
# 2  http://www.redfin.com/OR/Oregon-City/20414-OR-...
# 3  http://www.redfin.com/OR/Tigard/7833-SW-Alder-...
# 4  http://www.redfin.com/OR/Portland/6393-SE-Yamh...
#
#    SOURCE      MLS#  FAVORITE INTERESTED   LATITUDE   LONGITUDE
# 0    RMLS  20418593         N          Y  45.328852 -122.631600
# 1    RMLS  20430438         N          Y  45.504376 -122.746032
# 2    RMLS  20479232         N          Y  45.311266 -122.569703
# 3    RMLS  20276691         N          Y  45.404892 -122.757569
# 4    RMLS  20344443         N          Y  45.516562 -122.598256
#
# [5 rows x 27 columns]

# %%
data.describe()
# Out:
#        SOLD DATE  ZIP OR POSTAL CODE         PRICE        BEDS       BATHS  \
# count        0.0          350.000000  3.500000e+02  337.000000  336.000000
# mean         NaN        97151.160000  5.646622e+05    3.287834    2.443452
# std          NaN           88.766411  4.451523e+05    1.871688    2.469773
# min          NaN        97003.000000  4.500000e+04    0.000000    1.000000
# 25%          NaN        97062.000000  3.499125e+05    3.000000    2.000000
# 50%          NaN        97206.000000  4.490000e+05    3.000000    2.250000
# 75%          NaN        97221.000000  6.117488e+05    4.000000    2.500000
# max          NaN        97267.000000  3.900000e+06   30.000000   40.000000
#
#         SQUARE FEET      LOT SIZE   YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  \
# count    336.000000  2.660000e+02   336.000000      350.000000     336.000000
# mean    2096.538690  1.905295e+04  1979.779762        5.111429     274.467262
# std     1265.957486  8.342097e+04    31.827694       12.992907      95.572675
# min      521.000000  8.710000e+02  1903.000000        1.000000      41.000000
# 25%     1364.000000  4.791000e+03  1959.000000        1.000000     221.000000
# 50%     1790.500000  6.969000e+03  1984.500000        1.000000     251.500000
# 75%     2507.250000  1.001800e+04  2007.000000        2.000000     307.000000
# max    13000.000000  1.236232e+06  2021.000000       96.000000     965.000000
#
#          HOA/MONTH          MLS#    LATITUDE   LONGITUDE
# count   121.000000  3.500000e+02  350.000000  350.000000
# mean    241.909091  2.091123e+07   45.480461 -122.686583
# std     207.238751  1.067993e+07    0.063068    0.138679
# min       8.000000  2.000164e+07   45.253127 -123.024495
# 25%      81.000000  2.016724e+07   45.441754 -122.782039
# 50%     205.000000  2.034413e+07   45.494357 -122.680832
# 75%     354.000000  2.050771e+07   45.523323 -122.590147
# max    1083.000000  2.201073e+08   45.597069 -122.325278

# %%
data['BEDS'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data['SQUARE FEET'],data['PRICE'])
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(data['LONGITUDE'],data['PRICE'])
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')
