# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# A_sold = '97201-sold-6m.csv'
# B_sold = '97202-sold-6m.csv'

# %%
# A_sold = pd.read_csv(A_sold)
# B_sold = pd.read_csv(B_sold)

# %%
# sold_home_data = pd.merge(A_sold, B_sold, how="outer")
# sold_home_data.head(15)

# %%
# import glob
# import os
# os.chdir("Final-Project/Bryan/Download_Files")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
sold_home_data = 'combined_csv.csv'
sold_home_data = pd.read_csv(sold_home_data)
sold_home_data.head()
# Out:
#    SALE TYPE         SOLD DATE              PROPERTY TYPE  \
# 0  PAST SALE       June-1-2020  Single Family Residential
# 1  PAST SALE      April-3-2020  Single Family Residential
# 2  PAST SALE      July-24-2020  Single Family Residential
# 3  PAST SALE       July-6-2020  Single Family Residential
# 4  PAST SALE  February-28-2020  Single Family Residential
#
#                  ADDRESS      CITY STATE OR PROVINCE  ZIP OR POSTAL CODE  \
# 0     7415 N Wayland Ave  Portland                OR               97203
# 1        7906 N Wall Ave  Portland                OR               97203
# 2  8719 N Portsmouth Ave  Portland                OR               97203
# 3     10020 N Mohawk Ave  Portland                OR               97203
# 4      4755 N Oberlin St  Portland                OR               97203
#
#       PRICE  BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 0  585000.0   3.0    2.0  ...   Sold                         NaN
# 1  288000.0   2.0    1.0  ...   Sold                         NaN
# 2  410000.0   3.0    1.5  ...   Sold                         NaN
# 3  369900.0   3.0    1.0  ...   Sold                         NaN
# 4  475000.0   3.0    2.0  ...   Sold                         NaN
#
#    NEXT OPEN HOUSE END TIME  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#    URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0  http://www.redfin.com/OR/Portland/7415-N-Wayla...
# 1  http://www.redfin.com/OR/Portland/7906-N-Wall-...
# 2  http://www.redfin.com/OR/Portland/8719-N-Ports...
# 3  http://www.redfin.com/OR/Portland/10020-N-Moha...
# 4  http://www.redfin.com/OR/Portland/4755-N-Oberl...
#
#    SOURCE        MLS#  FAVORITE INTERESTED   LATITUDE   LONGITUDE
# 0    RMLS  20031907.0         N          Y  45.576608 -122.710837
# 1    RMLS  20659330.0         N          Y  45.585963 -122.728275
# 2    RMLS  20626301.0         N          Y  45.586146 -122.721683
# 3    RMLS  20196394.0         N          Y  45.597424 -122.744028
# 4    RMLS  20338906.0         N          Y  45.578472 -122.718148
#
# [5 rows x 27 columns]

# %%
# from os import chdir
# from glob import glob


# # Produce a single CSV after combining all files
# def produceOneCSV(list_of_files, file_out):
#    # Consolidate all CSV files into one object
#    result_obj = pd.concat([pd.read_csv(file) for file in list_of_files])
#    # Convert the above object into a csv file and export
#    result_obj.to_csv(file_out, index=False, encoding="utf-8")

# # Move to the path that holds our CSV files
# csv_file_path = 'c:/temp/csv_dir/'
# chdir(csv_file_path)

# # List all CSV files in the working dir
# file_pattern = ".csv"
# list_of_files = [file for file in glob('*.{}'.format(file_pattern))]
# print(list_of_files)

#file_out = "ConsolidateOutput.csv"
#produceOneCSV(list_of_files, file_out)
